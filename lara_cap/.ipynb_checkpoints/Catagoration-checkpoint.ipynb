# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from plotly.graph_objs import *
import plotly.plotly as py
import plotly.tools as tls

from sklearn.manifold import TSNE
import sklearn.cluster as cluster
import time

# %matplotlib inline
sns.set_context('poster')
sns.set_color_codes()
plot_kwds = {'alpha' : 0.25, 's' : 80, 'linewidths':0}

# %% [markdown]
# ### Import datasets

# %%
the_data = pd.read_csv('the_data.csv')
print "'the_data' dataset has {} samples with {} features each.".format(*the_data.shape)
# Out:
# 'the_data' dataset has 170842 samples with 83 features each.

# %%
big_data = pd.read_csv('big_data.csv')
print "'big_data' dataset has {} samples with {} features each.".format(*big_data.shape)
# Out:
# 'big_data' dataset has 170842 samples with 432 features each.

# %%
samples_data = pd.DataFrame(big_data.sample(n=7))
outta_data = pd.DataFrame(the_data)

# %%
plt.scatter(outta_data.T[0], outta_data.T[1], c='b', **plot_kwds)
frame = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

# %% [markdown]
# ### Dimensionality reduction
# There are many zeroes in our data. In the 'autus_data_clean' we manually merged and renamed some data. In this part I will use both the manually merged data ('the_data') and the dimensionality reducted data of 'big_data' where the datapoints have not been manually merged.

# %%
# %%time

from sklearn.decomposition import TruncatedSVD 
from sklearn.preprocessing import normalize 

svd = TruncatedSVD(n_components=10)
embedded_coords = normalize(svd.fit_transform(big_data), norm='l1')
# Out:
# CPU times: user 6.18 s, sys: 950 ms, total: 7.12 s
# Wall time: 4.63 s

# %%
pd.DataFrame(np.cumsum(svd.explained_variance_ratio_)).plot()

# %%
#Create a datafram out of the embedded_coords
embc = pd.DataFrame(embedded_coords)
embc.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.004065  0.664193 -0.124963  0.002270 -0.036614 -0.023516 -0.028118
# 1  0.003608  0.433562 -0.063550 -0.155179  0.326149 -0.006905  0.001671
# 2  0.005772  0.562352 -0.092668 -0.112062  0.168459  0.019478  0.006947
# 3  0.007344  0.710253 -0.134417 -0.005295 -0.041506 -0.004116 -0.017994
# 4  0.007311  0.460280  0.408239  0.030954 -0.001287  0.009655 -0.006387
#
#           7         8         9
# 0 -0.045221 -0.027705 -0.043336
# 1 -0.006322  0.001293  0.001761
# 2  0.004837  0.024892  0.002533
# 3 -0.032663 -0.008442 -0.037969
# 4  0.012791  0.031239  0.031857

# %%
#from sklearn.model_selection import train_test_split

#y = embc.pop(0) #pop removes the element in the index that is the first element
#X = embc

#X_train,X_test,y_train,y_test = train_test_split(X.index,y,test_size=0.2)
#X.iloc[X_train] # return dataframe train

# %%
#Decrease the data to make it easier to calculate
samples = embc.sample(n=7)
outta = embc.sample(n=5000)

# %%
plt.scatter(embc[0], embc[1], c='b', **plot_kwds)
frame = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

# %%
#Use the silhouette score to give us an idea of how many clusters there are in the data

from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score

cluster_range = list(range(2,6)) 
#Go through with different n_components to find the best silhouette score

for n_cluster in cluster_range:
    # TODO: Apply your clustering algorithm of choice to the reduced data 
    clusterer = KMeans(n_components = n_cluster, random_state=2).fit(outta)
    
    # TODO: Predict the cluster for each data point
    preds = clusterer.predict(outta)
    
    # TODO: Find the cluster centers
    centers = clusterer.means_
    
    # TODO: Predict the cluster for each transformed sample data point
    sample_preds = clusterer.predict(samples)
    
    # TODO: Calculate the mean silhouette coefficient for the number of clusters chosen
    score = silhouette_score(outta, preds)
    
    print "The score for n_cluster = {}. is : {}". format(n_cluster, score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d576a15ba2df> in <module>()
#       9 for n_cluster in cluster_range:
#      10     # TODO: Apply your clustering algorithm of choice to the reduced data
# ---> 11     clusterer = KMeans(n_components = n_cluster, random_state=2).fit(outta)
#      12
#      13     # TODO: Predict the cluster for each data point
#
# NameError: name 'KMeans' is not defined

# %%
sns.pairplot(outta, size=1.8)

# %%
# %%time

from scipy.stats import rankdata
embedded_ranks = np.array([rankdata(c) for c in embc.T]).T

from sklearn.cluster import KMeans
n_clusters = 2
km = KMeans(n_clusters)
clusters = km.fit_predict(outta)

# %%
clusterer = GaussianMixture(n_components = 2).fit(outta)
preds = clusterer.predict(outta)
centers = clusterer.means_
sample_preds = clusterer.predict(samples)

# Display the results of the clustering from implementation
vs.cluster_results(outta, preds, centers, pca_samples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7f1beb912cc1> in <module>()
# ----> 1 clusterer = GaussianMixture(n_components = 2).fit(outta)
#       2 preds = clusterer.predict(outta)
#       3 centers = clusterer.means_
#       4 sample_preds = clusterer.predict(samples)
#       5
#
# NameError: name 'GaussianMixture' is not defined

# %%
model = TSNE(n_components=2, random_state=0)
z = model.fit_transform(outta) 
dftsne = pd.DataFrame(z, columns=['x','y'])

# %%
def plot_clusters(data, algorithm, args, kwds):
    start_time = time.time()
    labels = algorithm(*args, **kwds).fit_predict(data)
    end_time = time.time()
    palette = sns.color_palette('deep', np.unique(labels).max() + 1)
    colors = [palette[x] if x >= 0 else (0.0, 0.0, 0.0) for x in labels]
    plt.scatter(data[0], data[1], c=colors, **plot_kwds)
    frame = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)
    plt.title('Clusters found by {}'.format(str(algorithm.__name__)), fontsize=24)
    plt.text(-0.5, 0.7, 'Clustering took {:.2f} s'.format(end_time - start_time), fontsize=14)

# %%
plot_clusters(outta, cluster.KMeans, (), {'n_clusters':2})

# %%
plot_clusters(outta, cluster.SpectralClustering, (), {'n_clusters':2})

# %%
labels = TSNE(n_components=2, random_state=0).fit_transform(outta)
print labels
# Out:
# [[  1.06886345   7.97062368]
#  [  7.42915474   2.08684678]
#  [  5.41091523  -7.92353663]
#  ...,
#  [ 10.57247126   1.72224097]
#  [  4.42504298  -6.47833165]
#  [ -8.56456952  -0.08675124]]

# %%
labels_frame = pd.DataFrame(labels)

plt.scatter(labels_frame[0], labels_frame[1])

# %%
#gera scatterplot með mismunandi litum fyrir cluster 1 og 2
#Hvernig er hægt að vita í hvaða cluster viðkomandi tilheyrir?

vis_x = labels[0]
vis_y = labels[1]

plt.scatter(vis_x, vis_y, c=labels, cmap=plt.cm.get_cmap('RdYlBu'))
plt.colorbar(ticks=range(10))
plt.clim(-0.5, 9.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-79fa319f4f86> in <module>()
#       2 vis_y = labels[1]
#       3
# ----> 4 plt.scatter(vis_x, vis_y, c=labels, cmap=plt.cm.get_cmap('RdYlBu'))
#       5 plt.colorbar(ticks=range(10))
#       6 plt.clim(-0.5, 9.5)
#
# //anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# //anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# //anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4026                 offsets=offsets,
#    4027                 transOffset=kwargs.pop('transform', self.transData),
# -> 4028                 alpha=alpha
#    4029                 )
#    4030         collection.set_transform(mtransforms.IdentityTransform())
#
# //anaconda/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, paths, sizes, **kwargs)
#     888         """
#     889
# --> 890         Collection.__init__(self, **kwargs)
#     891         self.set_paths(paths)
#     892         self.set_sizes(sizes)
#
# //anaconda/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, edgecolors, facecolors, linewidths, linestyles, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     137         self._is_filled = True  # May be modified by set_facecolor().
#     138
# --> 139         self.set_facecolor(facecolors)
#     140         self.set_edgecolor(edgecolors)
#     141         self.set_linewidth(linewidths)
#
# //anaconda/lib/python2.7/site-packages/matplotlib/collections.pyc in set_facecolor(self, c)
#     672         """
#     673         self._original_facecolor = c
# --> 674         self._set_facecolor(c)
#     675
#     676     def set_facecolors(self, c):
#
# //anaconda/lib/python2.7/site-packages/matplotlib/collections.pyc in _set_facecolor(self, c)
#     657         except AttributeError:
#     658             pass
# --> 659         self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     660         self.stale = True
#     661
#
# //anaconda/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba_array(c, alpha)
#     235     result = np.empty((len(c), 4), float)
#     236     for i, cc in enumerate(c):
# --> 237         result[i] = to_rgba(cc, alpha)
#     238     return result
#     239
#
# //anaconda/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba(c, alpha)
#     141         rgba = _colors_full_map.cache[c, alpha]
#     142     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 143         rgba = _to_rgba_no_colorcycle(c, alpha)
#     144         try:
#     145             _colors_full_map.cache[c, alpha] = rgba
#
# //anaconda/lib/python2.7/site-packages/matplotlib/colors.pyc in _to_rgba_no_colorcycle(c, alpha)
#     194         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     195     if len(c) not in [3, 4]:
# --> 196         raise ValueError("RGBA sequence should have length 3 or 4")
#     197     if len(c) == 3 and alpha is None:
#     198         alpha = 1
#
# ValueError: RGBA sequence should have length 3 or 4
